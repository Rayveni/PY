# %%
# Random Spiral Fractals
# FB36 - 20130929
import math
import random
from collections import deque
from PIL import Image
imgx = 1440; imgy = 900
image = Image.new("RGB", (imgx, imgy))
pixels = image.load()
xa = -1.5; xb = 1.5; ya = -1.5; yb = 1.5 # view
n = random.randint(2, 9) # of spiral arms
a = 2.0 * math.pi / n # angle between arms
t = 2.0 * math.pi * random.random() # rotation angle of central copy
r1 = 0.1 * random.random() + 0.1 # scale factor of outmost copies of the spiral arms
r0 = 1.0 - r1 # scale factor of central copy
ts = math.sin(t) * r0; tc = math.cos(t) * r0
maxIt = 64 # max number of iterations allowed
for ky in range(imgy):
     #print( str(100 * ky / (imgy - 1)).zfill(3) + "%")
    for kx in range(imgx):
        x = float(kx) / (imgx - 1) * (xb - xa) + xa
        y = float(ky) / (imgy - 1) * (yb - ya) + ya
        queue = deque([])
        queue.append((x, y, 0))
        while len(queue) > 0: # iterate points until none left
            (x, y, i) = queue.popleft()
            # apply all (inverse) IFS transformations
            for k in range(n + 1): # n outmost copies + central copy
                if k == n: # central copy
                    # inverse rotation and scaling
                    xnew = (y + x * tc / ts) / (ts + tc * tc / ts)
                    ynew = (y - x / tc * ts) / (tc + ts / tc * ts)
                else: # outmost copies on the spiral arms
                    c = k * a # angle
                    # inverse scaling and translation
                    xnew = (x - math.cos(c)) / r1
                    ynew = (y - math.sin(c)) / r1
                if xnew >= xa and xnew <= xb and ynew >= ya and ynew <= yb:
                    if i + 1 == maxIt: break
                    queue.append((xnew, ynew, i + 1))
        pixels[kx, ky] = (i % 16 * 16 , i % 8 * 32, i % 4 * 64)
#image.save("RandomSpiralFractal_" + str(n) + ".png", "PNG")
print(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1440x900 at 0x54B7668>

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=1440x900 at 0x54B7668>

# %%
# %%time
import math
import random
from PIL import Image
imgx = 256; imgy = 256; imgz = 256
image = Image.new("RGB", (imgx, imgy))
pixels = image.load()
print ("Creating voxels...")
# each voxel can have RGB color
voxelRGB = [[[(0, 0, 0) for x in range(imgx)] for y in range(imgy)] for z in range(imgz)]
# each voxel can have an opacity coefficient 0 or 1 (for simplicity)
opacity = [[[0 for x in range(imgx)] for y in range(imgy)] for z in range(imgz)]
eye = (imgx / 2.0, imgy / 2.0, -imgz / 2.0)
mx = imgx - 1; my = imgy - 1; mz = imgz - 1
f = 5.0 # roughness

def rnd():
    return (random.random() - .5) * f

def putvoxel(x, y, z, r, g, b):
    global voxelRGB, opacity
    x = int(round(x)); y = int(round(y)); z = int(round(z))
    voxelRGB[z][y][x] = (int(round(r)), int(round(g)), int(round(b)))
    opacity[z][y][x] = 1

def getvoxel(x, y, z):
    return voxelRGB[int(round(z))][int(round(y))][int(round(x))]

def CreatePlasmaCube(): # using non-recursive Diamond-square Algorithm
    global voxelRGB, opacity
    # corners
    for kz in range(2):
        for ky in range(2):
            for kx in range(2):
                putvoxel(mx * kx, my * ky, mz * kz, \
                    random.randint(0, 255), \
                    random.randint(0, 255), \
                    random.randint(0, 255))

    j = -1
    while True:
        j += 1; j2 = 2 ** j
        jx = float(mx) / j2; jy = float(my) / j2; jz = float(mz) / j2
        if jx < 1 and jy < 1 and jz < 1: break
        for m in range(j2):
            z0 = m * jz; z1 = z0 + jz; z = z0 + jz / 2.0        
            for i in range(j2):
                y0 = i * jy; y1 = y0 + jy; y = y0 + jy / 2.0        
                for k in range(j2):
                    x0 = k * jx; x1 = x0 + jx; x = x0 + jx / 2.0
                
                    a = getvoxel(x0, y0, z0); b = getvoxel(x1, y0, z0)
                    c = getvoxel(x0, y1, z0); d = getvoxel(x1, y1, z0)
                    e = getvoxel(x0, y0, z1); f = getvoxel(x1, y0, z1)
                    g = getvoxel(x0, y1, z1); h = getvoxel(x1, y1, z1)

                    # center
                    putvoxel(x, y, z, \
                        (a[0] + b[0] + c[0] + d[0] + e[0] + f[0] + g[0] + h[0]) / 8.0, \
                        (a[1] + b[1] + c[1] + d[1] + e[1] + f[1] + g[1] + h[1]) / 8.0, \
                        (a[2] + b[2] + c[2] + d[2] + e[2] + f[2] + g[2] + h[2]) / 8.0)

                    # centers of 6 faces
                    putvoxel(x, y, z0, \
                        (a[0] + b[0] + c[0] + d[0]) / 4.0, \
                        (a[1] + b[1] + c[1] + d[1]) / 4.0, \
                        (a[2] + b[2] + c[2] + d[2]) / 4.0)
                    putvoxel(x, y, z1, \
                        (e[0] + f[0] + g[0] + h[0]) / 4.0, \
                        (e[1] + f[1] + g[1] + h[1]) / 4.0, \
                        (e[2] + f[2] + g[2] + h[2]) / 4.0)
                    putvoxel(x, y0, z, \
                        (a[0] + b[0] + e[0] + f[0]) / 4.0, \
                        (a[1] + b[1] + e[1] + f[1]) / 4.0, \
                        (a[2] + b[2] + e[2] + f[2]) / 4.0)
                    putvoxel(x, y1, z, \
                        (c[0] + d[0] + g[0] + h[0]) / 4.0, \
                        (c[1] + d[1] + g[1] + h[1]) / 4.0, \
                        (c[2] + d[2] + g[2] + h[2]) / 4.0)
                    putvoxel(x0, y, z, \
                        (a[0] + c[0] + e[0] + g[0]) / 4.0, \
                        (a[1] + c[1] + e[1] + g[1]) / 4.0, \
                        (a[2] + c[2] + e[2] + g[2]) / 4.0)
                    putvoxel(x1, y, z, \
                        (b[0] + d[0] + f[0] + h[0]) / 4.0, \
                        (b[1] + d[1] + f[1] + h[1]) / 4.0, \
                        (b[2] + d[2] + f[2] + h[2]) / 4.0)

                    # centers of 12 edges
                    putvoxel(x, y0, z0, \
                        (a[0] + b[0]) / 2.0 + jx * rnd(), \
                        (a[1] + b[1]) / 2.0 + jx * rnd(), \
                        (a[2] + b[2]) / 2.0 + jx * rnd())
                    putvoxel(x0, y, z0, \
                        (a[0] + c[0]) / 2.0 + jy * rnd(), \
                        (a[1] + c[1]) / 2.0 + jy * rnd(), \
                        (a[2] + c[2]) / 2.0 + jy * rnd())
                    putvoxel(x1, y, z0, \
                        (b[0] + d[0]) / 2.0 + jy * rnd(), \
                        (b[1] + d[1]) / 2.0 + jy * rnd(), \
                        (b[2] + d[2]) / 2.0 + jy * rnd()) 
                    putvoxel(x, y1, z0, \
                        (c[0] + d[0]) / 2.0 + jx * rnd(), \
                        (c[1] + d[1]) / 2.0 + jx * rnd(), \
                        (c[2] + d[2]) / 2.0 + jx * rnd())
                    putvoxel(x, y0, z1, \
                        (e[0] + f[0]) / 2.0 + jx * rnd(), \
                        (e[1] + f[1]) / 2.0 + jx * rnd(), \
                        (e[2] + f[2]) / 2.0 + jx * rnd())
                    putvoxel(x0, y, z1, \
                        (e[0] + g[0]) / 2.0 + jy * rnd(), \
                        (e[1] + g[1]) / 2.0 + jy * rnd(), \
                        (e[2] + g[2]) / 2.0 + jy * rnd())
                    putvoxel(x1, y, z1, \
                        (f[0] + h[0]) / 2.0 + jy * rnd(), \
                        (f[1] + h[1]) / 2.0 + jy * rnd(), \
                        (f[2] + h[2]) / 2.0 + jy * rnd()) 
                    putvoxel(x, y1, z1, \
                        (g[0] + h[0]) / 2.0 + jx * rnd(), \
                        (g[1] + h[1]) / 2.0 + jx * rnd(), \
                        (g[2] + h[2]) / 2.0 + jx * rnd())
                    putvoxel(x0, y0, z, \
                        (a[0] + e[0]) / 2.0 + jz * rnd(), \
                        (a[1] + e[1]) / 2.0 + jz * rnd(), \
                        (a[2] + e[2]) / 2.0 + jz * rnd())
                    putvoxel(x1, y0, z, \
                        (b[0] + f[0]) / 2.0 + jz * rnd(), \
                        (b[1] + f[1]) / 2.0 + jz * rnd(), \
                        (b[2] + f[2]) / 2.0 + jz * rnd())
                    putvoxel(x0, y1, z, \
                        (c[0] + g[0]) / 2.0 + jz * rnd(), \
                        (c[1] + g[1]) / 2.0 + jz * rnd(), \
                        (c[2] + g[2]) / 2.0 + jz * rnd())
                    putvoxel(x1, y1, z, \
                        (d[0] + h[0]) / 2.0 + jz * rnd(), \
                        (d[1] + h[1]) / 2.0 + jz * rnd(), \
                        (d[2] + h[2]) / 2.0 + jz * rnd())

# cx, cy, cz: center; r: radius (in voxels)
def CreateSphere(cx, cy, cz, r):
    global voxelRGB, opacity
    # sphere is set of voxels which have distance = r to center
    for z in range(imgz):
        for y in range(imgy):
            for x in range(imgx):
                dx = x - cx
                dy = y - cy
                dz = z - cz
                d = math.sqrt(dx * dx + dy * dy + dz * dz)
                if abs(d - r) > 1.0:
                    voxelRGB[z][y][x] = (0, 0, 0)
                    opacity[z][y][x] = 0

# Ray Tracer (traces the ray and returns an RGB color)
def RayTrace(rayX, rayY, rayZ, dx, dy, dz):
    while True:
        rayX += dx; rayY += dy; rayZ += dz # move the ray by 1 voxel
        rayXint = int(round(rayX)); rayYint = int(round(rayY)); rayZint = int(round(rayZ))
        # if ray goes outside of the voxel-box
        if rayXint < 0 or rayXint > imgx - 1 \
            or rayYint < 0 or rayYint > imgy - 1 \
            or rayZint < 0 or rayZint > imgz - 1:
            return (0, 0, 0)
        # if ray hits an object
        if opacity[rayZint][rayYint][rayXint] == 1:
            return voxelRGB[rayZint][rayYint][rayXint]

def CreateScene():
    print ("Creating scene...")
    CreatePlasmaCube()
    CreateSphere(imgx / 2.0, imgy / 2.0, imgz / 2, min(imgx / 2.0, imgy / 2.0, imgz / 2))

def RenderScene():
    print ("Rendering scene...")
    for ky in range(imgy):
         #print str(100 * ky / (imgy - 1)).zfill(3) + "%"
        for kx in range(imgx):
            dx = kx - eye[0]
            dy = ky - eye[1]
            dz = 0.0 - eye[2]
            d = math.sqrt(dx * dx + dy * dy + dz * dz)
            dx = dx / d; dy = dy / d; dz = dz / d # ray unit vector
            pixels[kx, ky] = RayTrace(kx, ky, 0, dx, dy, dz)

# MAIN
CreateScene()
RenderScene()
#image.save("RandomPlanet.png", "PNG")
image
# Out:
# Creating voxels...
# Creating scene...
# Rendering scene...
# Wall time: 7min 48s

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x1BF96E48>

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x6B87198>

# %%
# Quasicrystal Pattern Generator
# https://en.wikipedia.org/wiki/Quasicrystal
# http://mainisusuallyafunction.blogspot.com/2011/10/quasicrystals-as-sums-of-waves-in-plane.html
# FB - 20150808
import math
import random
from PIL import Image
imgx = 512; imgy = 512
image = Image.new("RGB", (imgx, imgy))
pixels = image.load()

f = random.random() * 40 + 10 # frequency
p = random.random() * math.pi # phase
n = random.randint(10, 20) # of rotations
print( f, p, n)

for ky in range(imgy):
    y = float(ky) / (imgy - 1) * 4 * math.pi - 2 * math.pi
    for kx in range(imgx):
        x = float(kx) / (imgx - 1) * 4 * math.pi - 2 * math.pi
        z = 0.0
        for i in range(n):
            r = math.hypot(x, y)
            a = math.atan2(y, x) + i * math.pi * 2.0 / n
            z += math.cos(r * math.sin(a) * f + p)
        c = int(round(255 * z / n))
        pixels[kx, ky] = (c, c, c) # grayscale
image
# Out:
# 13.194942608192942 0.5459289249472468 10
# <PIL.Image.Image image mode=RGB size=512x512 at 0x4BC17B8>

# %%
# Snowflake Simulation Using Reiter Cellular Automata
# Source: "A Local Cellular Model for Snow Crystal Growth" by Cliff Reiter
# FB36 - 20130107
import math
import random
from PIL import Image, ImageDraw
imgx = 500; imgy = 500 # image size
imgx1 = imgx - 1; imgy1 = imgy - 1
image = Image.new("RGB", (imgx, imgy))
draw = ImageDraw.Draw(image)
pixels = image.load()
maxIt = 1000 # of growth steps
# snowflake will differ depending on values of these parameters:
alpha = random.random() * 1.5 + 0.5
beta = random.random() * 0.3 + 0.3
gamma = random.random() * 0.01
mx = 250; my = 250 # width and height of 2DCA
ca = [[beta for x in range(mx)] for y in range(my)]
caRep = [[beta for x in range(mx)] for y in range(my)] # receptive cells
caNRep = [[beta for x in range(mx)] for y in range(my)] # non-receptive cells
dx = [-1, 0, -1, 1, 0, 1]; dy = [-1, -1, 0, 0, 1, 1] # 6 directions to grow
# these are for coloring the image
while True:
    mr0 = 2 ** random.randint(3, 6); mr1 = 256 / mr0
    mg0 = 2 ** random.randint(3, 6); mg1 = 256 / mg0
    mb0 = 2 ** random.randint(3, 6); mb1 = 256 / mb0
    if mr0 != mg0 and mr0 != mb0 and mg0 != mb0: break

ca[int((my - 1) / 2)][int((mx - 1) / 2)] = 1.0 # ice seed
for i in range(maxIt): # growth steps
    print ("Growth Step: " + str(i + 1) + " of " + str(maxIt))
    # separate the array into receptive and non-receptive arrays
    for iy in range(my):
        for ix in range(mx):
            receptive = False
            if ca[iy][ix] >= 1.0: # ice
                receptive = True
            else: # check neighbors
                for j in range(6):
                    jx = ix + dx[j]; jy = iy + dy[j]
                    if jx >= 0 and jx < mx and jy >= 0 and jy < my:
                        if ca[jy][jx] >= 1.0: # ice
                            receptive = True
                            break
            if receptive:
                caRep[iy][ix] = ca[iy][ix] + gamma
                caNRep[iy][ix] = 0.0
            else:
                caRep[iy][ix] = 0.0
                caNRep[iy][ix] = ca[iy][ix]

    # new array: weighed averages of the non-receptive array + receptive array
    for iy in range(my):
        for ix in range(mx):
            wsum = caNRep[iy][ix] * (1.0 - alpha * 6.0 / 12.0)
            for j in range(6): # neighbors
                jx = ix + dx[j]; jy = iy + dy[j]
                if jx >= 0 and jx < mx and jy >= 0 and jy < my:
                    wsum += caNRep[jy][jx] * alpha / 12.0
            ca[iy][ix] = caRep[iy][ix] + wsum

# paint final state of the snowflake
an45 = - math.pi / 4.0
sn45 = math.sin(an45); cs45 = math.cos(an45)
scale = math.sqrt(3.0); ox = imgx1 / 2.0; oy = imgy1 / 2.0
for ky in range(imgy):
    for kx in range(imgx):
        # apply geometric transformation (scaling and rotation)
        tx = kx - ox; ty = (ky - oy) * scale
        tx0 = tx * cs45 - ty * sn45 + ox
        ty = tx * sn45 + ty * cs45 + oy; tx = tx0
        if tx >= 0 and tx <= imgx1 and ty >= 0 and ty <= imgy1:
            c = ca[int((my - 1) * ty / imgy1)][int((mx - 1) * tx / imgx1)]
            if c >= 1.0: # ice
                c = int((c - 1.0) * 255)
                pixels[kx, ky] = (int(c % mr0 * mr1), int(c % mg0 * mg1), int(c % mb0 * mb1))
label = "alpha = " + str(alpha) + " beta = " + str(beta) + " gamma = " + str(gamma)
draw.text((0, 0), label, (0, 255, 0)) # write to top-left using green color
image.save("Snowflake.png", "PNG")
# Out:
# Growth Step: 1 of 1000
# Growth Step: 2 of 1000
# Growth Step: 3 of 1000
# Growth Step: 4 of 1000
# Growth Step: 5 of 1000
# Growth Step: 6 of 1000
# Growth Step: 7 of 1000
# Growth Step: 8 of 1000
# Growth Step: 9 of 1000
# Growth Step: 10 of 1000
# Growth Step: 11 of 1000
# Growth Step: 12 of 1000
# Growth Step: 13 of 1000
# Growth Step: 14 of 1000
# Growth Step: 15 of 1000
# Growth Step: 16 of 1000
# Growth Step: 17 of 1000
# Growth Step: 18 of 1000
# Growth Step: 19 of 1000
# Growth Step: 20 of 1000
# Growth Step: 21 of 1000
# Growth Step: 22 of 1000
# Growth Step: 23 of 1000
# Growth Step: 24 of 1000
# Growth Step: 25 of 1000
# Growth Step: 26 of 1000
# Growth Step: 27 of 1000
# Growth Step: 28 of 1000
# Growth Step: 29 of 1000
# Growth Step: 30 of 1000
# Growth Step: 31 of 1000
# Growth Step: 32 of 1000
# Growth Step: 33 of 1000
# Growth Step: 34 of 1000
# Growth Step: 35 of 1000
# Growth Step: 36 of 1000
# Growth Step: 37 of 1000
# Growth Step: 38 of 1000
# Growth Step: 39 of 1000
# Growth Step: 40 of 1000
# Growth Step: 41 of 1000
# Growth Step: 42 of 1000
# Growth Step: 43 of 1000
# Growth Step: 44 of 1000
# Growth Step: 45 of 1000
# Growth Step: 46 of 1000
# Growth Step: 47 of 1000
# Growth Step: 48 of 1000
# Growth Step: 49 of 1000
# Growth Step: 50 of 1000
# Growth Step: 51 of 1000
# Growth Step: 52 of 1000
# Growth Step: 53 of 1000
# Growth Step: 54 of 1000
# Growth Step: 55 of 1000
# Growth Step: 56 of 1000
# Growth Step: 57 of 1000
# Growth Step: 58 of 1000
# Growth Step: 59 of 1000
# Growth Step: 60 of 1000
# Growth Step: 61 of 1000
# Growth Step: 62 of 1000
# Growth Step: 63 of 1000
# Growth Step: 64 of 1000
# Growth Step: 65 of 1000
# Growth Step: 66 of 1000
# Growth Step: 67 of 1000
# Growth Step: 68 of 1000
# Growth Step: 69 of 1000
# Growth Step: 70 of 1000
# Growth Step: 71 of 1000
# Growth Step: 72 of 1000
# Growth Step: 73 of 1000
# Growth Step: 74 of 1000
# Growth Step: 75 of 1000
# Growth Step: 76 of 1000
# Growth Step: 77 of 1000
# Growth Step: 78 of 1000
# Growth Step: 79 of 1000
# Growth Step: 80 of 1000
# Growth Step: 81 of 1000
# Growth Step: 82 of 1000
# Growth Step: 83 of 1000
# Growth Step: 84 of 1000
# Growth Step: 85 of 1000
# Growth Step: 86 of 1000
# Growth Step: 87 of 1000
# Growth Step: 88 of 1000
# Growth Step: 89 of 1000
# Growth Step: 90 of 1000
# Growth Step: 91 of 1000
# Growth Step: 92 of 1000
# Growth Step: 93 of 1000
# Growth Step: 94 of 1000
# Growth Step: 95 of 1000
# Growth Step: 96 of 1000
# Growth Step: 97 of 1000
# Growth Step: 98 of 1000
# Growth Step: 99 of 1000
# Growth Step: 100 of 1000
# Growth Step: 101 of 1000
# Growth Step: 102 of 1000
# Growth Step: 103 of 1000
# Growth Step: 104 of 1000
# Growth Step: 105 of 1000
# Growth Step: 106 of 1000
# Growth Step: 107 of 1000
# Growth Step: 108 of 1000
# Growth Step: 109 of 1000
# Growth Step: 110 of 1000
# Growth Step: 111 of 1000
# Growth Step: 112 of 1000
# Growth Step: 113 of 1000
# Growth Step: 114 of 1000
# Growth Step: 115 of 1000
# Growth Step: 116 of 1000
# Growth Step: 117 of 1000
# Growth Step: 118 of 1000
# Growth Step: 119 of 1000
# Growth Step: 120 of 1000
# Growth Step: 121 of 1000
# Growth Step: 122 of 1000
# Growth Step: 123 of 1000
# Growth Step: 124 of 1000
# Growth Step: 125 of 1000
# Growth Step: 126 of 1000
# Growth Step: 127 of 1000
# Growth Step: 128 of 1000
# Growth Step: 129 of 1000
# Growth Step: 130 of 1000
# Growth Step: 131 of 1000
# Growth Step: 132 of 1000
# Growth Step: 133 of 1000
# Growth Step: 134 of 1000
# Growth Step: 135 of 1000
# Growth Step: 136 of 1000
# Growth Step: 137 of 1000
# Growth Step: 138 of 1000
# Growth Step: 139 of 1000
# Growth Step: 140 of 1000
# Growth Step: 141 of 1000
# Growth Step: 142 of 1000
# Growth Step: 143 of 1000
# Growth Step: 144 of 1000
# Growth Step: 145 of 1000
# Growth Step: 146 of 1000
# Growth Step: 147 of 1000
# Growth Step: 148 of 1000
# Growth Step: 149 of 1000
# Growth Step: 150 of 1000
# Growth Step: 151 of 1000
# Growth Step: 152 of 1000
# Growth Step: 153 of 1000
# Growth Step: 154 of 1000
# Growth Step: 155 of 1000
# Growth Step: 156 of 1000
# Growth Step: 157 of 1000
# Growth Step: 158 of 1000
# Growth Step: 159 of 1000
# Growth Step: 160 of 1000
# Growth Step: 161 of 1000
# Growth Step: 162 of 1000
# Growth Step: 163 of 1000
# Growth Step: 164 of 1000
# Growth Step: 165 of 1000
# Growth Step: 166 of 1000
# Growth Step: 167 of 1000
# Growth Step: 168 of 1000
# Growth Step: 169 of 1000
# Growth Step: 170 of 1000
# Growth Step: 171 of 1000
# Growth Step: 172 of 1000
# Growth Step: 173 of 1000
# Growth Step: 174 of 1000
# Growth Step: 175 of 1000
# Growth Step: 176 of 1000
# Growth Step: 177 of 1000
# Growth Step: 178 of 1000
# Growth Step: 179 of 1000
# Growth Step: 180 of 1000
# Growth Step: 181 of 1000
# Growth Step: 182 of 1000
# Growth Step: 183 of 1000
# Growth Step: 184 of 1000
# Growth Step: 185 of 1000
# Growth Step: 186 of 1000
# Growth Step: 187 of 1000
# Growth Step: 188 of 1000
# Growth Step: 189 of 1000
# Growth Step: 190 of 1000
# Growth Step: 191 of 1000
# Growth Step: 192 of 1000
# Growth Step: 193 of 1000
# Growth Step: 194 of 1000
# Growth Step: 195 of 1000
# Growth Step: 196 of 1000
# Growth Step: 197 of 1000
# Growth Step: 198 of 1000
# Growth Step: 199 of 1000
# Growth Step: 200 of 1000
# Growth Step: 201 of 1000
# Growth Step: 202 of 1000
# Growth Step: 203 of 1000
# Growth Step: 204 of 1000
# Growth Step: 205 of 1000
# Growth Step: 206 of 1000
# Growth Step: 207 of 1000
# Growth Step: 208 of 1000
# Growth Step: 209 of 1000
# Growth Step: 210 of 1000
# Growth Step: 211 of 1000
# Growth Step: 212 of 1000
# Growth Step: 213 of 1000
# Growth Step: 214 of 1000
# Growth Step: 215 of 1000
# Growth Step: 216 of 1000
# Growth Step: 217 of 1000
# Growth Step: 218 of 1000
# Growth Step: 219 of 1000
# Growth Step: 220 of 1000
# Growth Step: 221 of 1000
# Growth Step: 222 of 1000
# Growth Step: 223 of 1000
# Growth Step: 224 of 1000
# Growth Step: 225 of 1000
# Growth Step: 226 of 1000
# Growth Step: 227 of 1000
# Growth Step: 228 of 1000
# Growth Step: 229 of 1000
# Growth Step: 230 of 1000
# Growth Step: 231 of 1000
# Growth Step: 232 of 1000
# Growth Step: 233 of 1000
# Growth Step: 234 of 1000
# Growth Step: 235 of 1000
# Growth Step: 236 of 1000
# Growth Step: 237 of 1000
# Growth Step: 238 of 1000
# Growth Step: 239 of 1000
# Growth Step: 240 of 1000
# Growth Step: 241 of 1000
# Growth Step: 242 of 1000
# Growth Step: 243 of 1000
# Growth Step: 244 of 1000
# Growth Step: 245 of 1000
# Growth Step: 246 of 1000
# Growth Step: 247 of 1000
# Growth Step: 248 of 1000
# Growth Step: 249 of 1000
# Growth Step: 250 of 1000
# Growth Step: 251 of 1000
# Growth Step: 252 of 1000
# Growth Step: 253 of 1000
# Growth Step: 254 of 1000
# Growth Step: 255 of 1000
# Growth Step: 256 of 1000
# Growth Step: 257 of 1000
# Growth Step: 258 of 1000
# Growth Step: 259 of 1000
# Growth Step: 260 of 1000
# Growth Step: 261 of 1000
# Growth Step: 262 of 1000
# Growth Step: 263 of 1000
# Growth Step: 264 of 1000
# Growth Step: 265 of 1000
# Growth Step: 266 of 1000
# Growth Step: 267 of 1000
# Growth Step: 268 of 1000
# Growth Step: 269 of 1000
# Growth Step: 270 of 1000
# Growth Step: 271 of 1000
# Growth Step: 272 of 1000
# Growth Step: 273 of 1000
# Growth Step: 274 of 1000
# Growth Step: 275 of 1000
# Growth Step: 276 of 1000
# Growth Step: 277 of 1000
# Growth Step: 278 of 1000
# Growth Step: 279 of 1000
# Growth Step: 280 of 1000
# Growth Step: 281 of 1000
# Growth Step: 282 of 1000
# Growth Step: 283 of 1000
# Growth Step: 284 of 1000
# Growth Step: 285 of 1000
# Growth Step: 286 of 1000
# Growth Step: 287 of 1000
# Growth Step: 288 of 1000
# Growth Step: 289 of 1000
# Growth Step: 290 of 1000
# Growth Step: 291 of 1000
# Growth Step: 292 of 1000
# Growth Step: 293 of 1000
# Growth Step: 294 of 1000
# Growth Step: 295 of 1000
# Growth Step: 296 of 1000
# Growth Step: 297 of 1000
# Growth Step: 298 of 1000
# Growth Step: 299 of 1000
# Growth Step: 300 of 1000
# Growth Step: 301 of 1000
# Growth Step: 302 of 1000
# Growth Step: 303 of 1000
# Growth Step: 304 of 1000
# Growth Step: 305 of 1000
# Growth Step: 306 of 1000
# Growth Step: 307 of 1000
# Growth Step: 308 of 1000
# Growth Step: 309 of 1000
# Growth Step: 310 of 1000
# Growth Step: 311 of 1000
# Growth Step: 312 of 1000
# Growth Step: 313 of 1000
# Growth Step: 314 of 1000
# Growth Step: 315 of 1000
# Growth Step: 316 of 1000
# Growth Step: 317 of 1000
# Growth Step: 318 of 1000
# Growth Step: 319 of 1000
# Growth Step: 320 of 1000
# Growth Step: 321 of 1000
# Growth Step: 322 of 1000
# Growth Step: 323 of 1000
# Growth Step: 324 of 1000
# Growth Step: 325 of 1000
# Growth Step: 326 of 1000
# Growth Step: 327 of 1000
# Growth Step: 328 of 1000
# Growth Step: 329 of 1000
# Growth Step: 330 of 1000
# Growth Step: 331 of 1000
# Growth Step: 332 of 1000
# Growth Step: 333 of 1000
# Growth Step: 334 of 1000
# Growth Step: 335 of 1000
# Growth Step: 336 of 1000
# Growth Step: 337 of 1000
# Growth Step: 338 of 1000
# Growth Step: 339 of 1000
# Growth Step: 340 of 1000
# Growth Step: 341 of 1000
# Growth Step: 342 of 1000
# Growth Step: 343 of 1000
# Growth Step: 344 of 1000
# Growth Step: 345 of 1000
# Growth Step: 346 of 1000
# Growth Step: 347 of 1000
# Growth Step: 348 of 1000
# Growth Step: 349 of 1000
# Growth Step: 350 of 1000
# Growth Step: 351 of 1000
# Growth Step: 352 of 1000
# Growth Step: 353 of 1000
# Growth Step: 354 of 1000
# Growth Step: 355 of 1000
# Growth Step: 356 of 1000
# Growth Step: 357 of 1000
# Growth Step: 358 of 1000
# Growth Step: 359 of 1000
# Growth Step: 360 of 1000
# Growth Step: 361 of 1000
# Growth Step: 362 of 1000
# Growth Step: 363 of 1000
# Growth Step: 364 of 1000
# Growth Step: 365 of 1000
# Growth Step: 366 of 1000
# Growth Step: 367 of 1000
# Growth Step: 368 of 1000
# Growth Step: 369 of 1000
# Growth Step: 370 of 1000
# Growth Step: 371 of 1000
# Growth Step: 372 of 1000
# Growth Step: 373 of 1000
# Growth Step: 374 of 1000
# Growth Step: 375 of 1000
# Growth Step: 376 of 1000
# Growth Step: 377 of 1000
# Growth Step: 378 of 1000
# Growth Step: 379 of 1000
# Growth Step: 380 of 1000
# Growth Step: 381 of 1000
# Growth Step: 382 of 1000
# Growth Step: 383 of 1000
# Growth Step: 384 of 1000
# Growth Step: 385 of 1000
# Growth Step: 386 of 1000
# Growth Step: 387 of 1000
# Growth Step: 388 of 1000
# Growth Step: 389 of 1000
# Growth Step: 390 of 1000
# Growth Step: 391 of 1000
# Growth Step: 392 of 1000
# Growth Step: 393 of 1000
# Growth Step: 394 of 1000
# Growth Step: 395 of 1000
# Growth Step: 396 of 1000
# Growth Step: 397 of 1000
# Growth Step: 398 of 1000
# Growth Step: 399 of 1000
# Growth Step: 400 of 1000
# Growth Step: 401 of 1000
# Growth Step: 402 of 1000
# Growth Step: 403 of 1000
# Growth Step: 404 of 1000
# Growth Step: 405 of 1000
# Growth Step: 406 of 1000
# Growth Step: 407 of 1000
# Growth Step: 408 of 1000
# Growth Step: 409 of 1000
# Growth Step: 410 of 1000
# Growth Step: 411 of 1000
# Growth Step: 412 of 1000
# Growth Step: 413 of 1000
# Growth Step: 414 of 1000
# Growth Step: 415 of 1000
# Growth Step: 416 of 1000
# Growth Step: 417 of 1000
# Growth Step: 418 of 1000
# Growth Step: 419 of 1000
# Growth Step: 420 of 1000
# Growth Step: 421 of 1000
# Growth Step: 422 of 1000
# Growth Step: 423 of 1000
# Growth Step: 424 of 1000
# Growth Step: 425 of 1000
# Growth Step: 426 of 1000
# Growth Step: 427 of 1000
# Growth Step: 428 of 1000
# Growth Step: 429 of 1000
# Growth Step: 430 of 1000
# Growth Step: 431 of 1000
# Growth Step: 432 of 1000
# Growth Step: 433 of 1000
# Growth Step: 434 of 1000
# Growth Step: 435 of 1000
# Growth Step: 436 of 1000
# Growth Step: 437 of 1000
# Growth Step: 438 of 1000
# Growth Step: 439 of 1000
# Growth Step: 440 of 1000
# Growth Step: 441 of 1000
# Growth Step: 442 of 1000
# Growth Step: 443 of 1000
# Growth Step: 444 of 1000
# Growth Step: 445 of 1000
# Growth Step: 446 of 1000
# Growth Step: 447 of 1000
# Growth Step: 448 of 1000
# Growth Step: 449 of 1000
# Growth Step: 450 of 1000
# Growth Step: 451 of 1000
# Growth Step: 452 of 1000
# Growth Step: 453 of 1000
# Growth Step: 454 of 1000
# Growth Step: 455 of 1000
# Growth Step: 456 of 1000
# Growth Step: 457 of 1000
# Growth Step: 458 of 1000
# Growth Step: 459 of 1000
# Growth Step: 460 of 1000
# Growth Step: 461 of 1000
# Growth Step: 462 of 1000
# Growth Step: 463 of 1000
# Growth Step: 464 of 1000
# Growth Step: 465 of 1000
# Growth Step: 466 of 1000
# Growth Step: 467 of 1000
# Growth Step: 468 of 1000
# Growth Step: 469 of 1000
# Growth Step: 470 of 1000
# Growth Step: 471 of 1000
# Growth Step: 472 of 1000
# Growth Step: 473 of 1000
# Growth Step: 474 of 1000
# Growth Step: 475 of 1000
# Growth Step: 476 of 1000
# Growth Step: 477 of 1000
# Growth Step: 478 of 1000
# Growth Step: 479 of 1000
# Growth Step: 480 of 1000
# Growth Step: 481 of 1000
# Growth Step: 482 of 1000
# Growth Step: 483 of 1000
# Growth Step: 484 of 1000
# Growth Step: 485 of 1000
# Growth Step: 486 of 1000
# Growth Step: 487 of 1000
# Growth Step: 488 of 1000
# Growth Step: 489 of 1000
# Growth Step: 490 of 1000
# Growth Step: 491 of 1000
# Growth Step: 492 of 1000
# Growth Step: 493 of 1000
# Growth Step: 494 of 1000
# Growth Step: 495 of 1000
# Growth Step: 496 of 1000
# Growth Step: 497 of 1000
# Growth Step: 498 of 1000
# Growth Step: 499 of 1000
# Growth Step: 500 of 1000
# Growth Step: 501 of 1000
# Growth Step: 502 of 1000
# Growth Step: 503 of 1000
# Growth Step: 504 of 1000
# Growth Step: 505 of 1000
# Growth Step: 506 of 1000
# Growth Step: 507 of 1000
# Growth Step: 508 of 1000
# Growth Step: 509 of 1000
# Growth Step: 510 of 1000
# Growth Step: 511 of 1000
# Growth Step: 512 of 1000
# Growth Step: 513 of 1000
# Growth Step: 514 of 1000
# Growth Step: 515 of 1000
# Growth Step: 516 of 1000
# Growth Step: 517 of 1000
# Growth Step: 518 of 1000
# Growth Step: 519 of 1000
# Growth Step: 520 of 1000
# Growth Step: 521 of 1000
# Growth Step: 522 of 1000
# Growth Step: 523 of 1000
# Growth Step: 524 of 1000
# Growth Step: 525 of 1000
# Growth Step: 526 of 1000
# Growth Step: 527 of 1000
# Growth Step: 528 of 1000
# Growth Step: 529 of 1000
# Growth Step: 530 of 1000
# Growth Step: 531 of 1000
# Growth Step: 532 of 1000
# Growth Step: 533 of 1000
# Growth Step: 534 of 1000
# Growth Step: 535 of 1000
# Growth Step: 536 of 1000
# Growth Step: 537 of 1000
# Growth Step: 538 of 1000
# Growth Step: 539 of 1000
# Growth Step: 540 of 1000
# Growth Step: 541 of 1000
# Growth Step: 542 of 1000
# Growth Step: 543 of 1000
# Growth Step: 544 of 1000
# Growth Step: 545 of 1000
# Growth Step: 546 of 1000
# Growth Step: 547 of 1000
# Growth Step: 548 of 1000
# Growth Step: 549 of 1000
# Growth Step: 550 of 1000
# Growth Step: 551 of 1000
# Growth Step: 552 of 1000
# Growth Step: 553 of 1000
# Growth Step: 554 of 1000
# Growth Step: 555 of 1000
# Growth Step: 556 of 1000
# Growth Step: 557 of 1000
# Growth Step: 558 of 1000
# Growth Step: 559 of 1000
# Growth Step: 560 of 1000
# Growth Step: 561 of 1000
# Growth Step: 562 of 1000
# Growth Step: 563 of 1000
# Growth Step: 564 of 1000
# Growth Step: 565 of 1000
# Growth Step: 566 of 1000
# Growth Step: 567 of 1000
# Growth Step: 568 of 1000
# Growth Step: 569 of 1000
# Growth Step: 570 of 1000
# Growth Step: 571 of 1000
# Growth Step: 572 of 1000
# Growth Step: 573 of 1000
# Growth Step: 574 of 1000
# Growth Step: 575 of 1000
# Growth Step: 576 of 1000
# Growth Step: 577 of 1000
# Growth Step: 578 of 1000
# Growth Step: 579 of 1000
# Growth Step: 580 of 1000
# Growth Step: 581 of 1000
# Growth Step: 582 of 1000
# Growth Step: 583 of 1000
# Growth Step: 584 of 1000
# Growth Step: 585 of 1000
# Growth Step: 586 of 1000
# Growth Step: 587 of 1000
# Growth Step: 588 of 1000
# Growth Step: 589 of 1000
# Growth Step: 590 of 1000
# Growth Step: 591 of 1000
# Growth Step: 592 of 1000
# Growth Step: 593 of 1000
# Growth Step: 594 of 1000
# Growth Step: 595 of 1000
# Growth Step: 596 of 1000
# Growth Step: 597 of 1000
# Growth Step: 598 of 1000
# Growth Step: 599 of 1000
# Growth Step: 600 of 1000
# Growth Step: 601 of 1000
# Growth Step: 602 of 1000
# Growth Step: 603 of 1000
# Growth Step: 604 of 1000
# Growth Step: 605 of 1000
# Growth Step: 606 of 1000
# Growth Step: 607 of 1000
# Growth Step: 608 of 1000
# Growth Step: 609 of 1000
# Growth Step: 610 of 1000
# Growth Step: 611 of 1000
# Growth Step: 612 of 1000
# Growth Step: 613 of 1000
# Growth Step: 614 of 1000
# Growth Step: 615 of 1000
# Growth Step: 616 of 1000
# Growth Step: 617 of 1000
# Growth Step: 618 of 1000
# Growth Step: 619 of 1000
# Growth Step: 620 of 1000
# Growth Step: 621 of 1000
# Growth Step: 622 of 1000
# Growth Step: 623 of 1000
# Growth Step: 624 of 1000
# Growth Step: 625 of 1000
# Growth Step: 626 of 1000
# Growth Step: 627 of 1000
# Growth Step: 628 of 1000
# Growth Step: 629 of 1000
# Growth Step: 630 of 1000
# Growth Step: 631 of 1000
# Growth Step: 632 of 1000
# Growth Step: 633 of 1000
# Growth Step: 634 of 1000
# Growth Step: 635 of 1000
# Growth Step: 636 of 1000
# Growth Step: 637 of 1000
# Growth Step: 638 of 1000
# Growth Step: 639 of 1000
# Growth Step: 640 of 1000
# Growth Step: 641 of 1000
# Growth Step: 642 of 1000
# Growth Step: 643 of 1000
# Growth Step: 644 of 1000
# Growth Step: 645 of 1000
# Growth Step: 646 of 1000
# Growth Step: 647 of 1000
# Growth Step: 648 of 1000
# Growth Step: 649 of 1000
# Growth Step: 650 of 1000
# Growth Step: 651 of 1000
# Growth Step: 652 of 1000
# Growth Step: 653 of 1000
# Growth Step: 654 of 1000
# Growth Step: 655 of 1000
# Growth Step: 656 of 1000
# Growth Step: 657 of 1000
# Growth Step: 658 of 1000
# Growth Step: 659 of 1000
# Growth Step: 660 of 1000
# Growth Step: 661 of 1000
# Growth Step: 662 of 1000
# Growth Step: 663 of 1000
# Growth Step: 664 of 1000
# Growth Step: 665 of 1000
# Growth Step: 666 of 1000
# Growth Step: 667 of 1000
# Growth Step: 668 of 1000
# Growth Step: 669 of 1000
# Growth Step: 670 of 1000
# Growth Step: 671 of 1000
# Growth Step: 672 of 1000
# Growth Step: 673 of 1000
# Growth Step: 674 of 1000
# Growth Step: 675 of 1000
# Growth Step: 676 of 1000
# Growth Step: 677 of 1000
# Growth Step: 678 of 1000
# Growth Step: 679 of 1000
# Growth Step: 680 of 1000
# Growth Step: 681 of 1000
# Growth Step: 682 of 1000
# Growth Step: 683 of 1000
# Growth Step: 684 of 1000
# Growth Step: 685 of 1000
# Growth Step: 686 of 1000
# Growth Step: 687 of 1000
# Growth Step: 688 of 1000
# Growth Step: 689 of 1000
# Growth Step: 690 of 1000
# Growth Step: 691 of 1000
# Growth Step: 692 of 1000
# Growth Step: 693 of 1000
# Growth Step: 694 of 1000
# Growth Step: 695 of 1000
# Growth Step: 696 of 1000
# Growth Step: 697 of 1000
# Growth Step: 698 of 1000
# Growth Step: 699 of 1000
# Growth Step: 700 of 1000
# Growth Step: 701 of 1000
# Growth Step: 702 of 1000
# Growth Step: 703 of 1000
# Growth Step: 704 of 1000
# Growth Step: 705 of 1000
# Growth Step: 706 of 1000
# Growth Step: 707 of 1000
# Growth Step: 708 of 1000
# Growth Step: 709 of 1000
# Growth Step: 710 of 1000
# Growth Step: 711 of 1000
# Growth Step: 712 of 1000
# Growth Step: 713 of 1000
# Growth Step: 714 of 1000
# Growth Step: 715 of 1000
# Growth Step: 716 of 1000
# Growth Step: 717 of 1000
# Growth Step: 718 of 1000
# Growth Step: 719 of 1000
# Growth Step: 720 of 1000
# Growth Step: 721 of 1000
# Growth Step: 722 of 1000
# Growth Step: 723 of 1000
# Growth Step: 724 of 1000
# Growth Step: 725 of 1000
# Growth Step: 726 of 1000
# Growth Step: 727 of 1000
# Growth Step: 728 of 1000
# Growth Step: 729 of 1000
# Growth Step: 730 of 1000
# Growth Step: 731 of 1000
# Growth Step: 732 of 1000
# Growth Step: 733 of 1000
# Growth Step: 734 of 1000
# Growth Step: 735 of 1000
# Growth Step: 736 of 1000
# Growth Step: 737 of 1000
# Growth Step: 738 of 1000
# Growth Step: 739 of 1000
# Growth Step: 740 of 1000
# Growth Step: 741 of 1000
# Growth Step: 742 of 1000
# Growth Step: 743 of 1000
# Growth Step: 744 of 1000
# Growth Step: 745 of 1000
# Growth Step: 746 of 1000
# Growth Step: 747 of 1000
# Growth Step: 748 of 1000
# Growth Step: 749 of 1000
# Growth Step: 750 of 1000
# Growth Step: 751 of 1000
# Growth Step: 752 of 1000
# Growth Step: 753 of 1000
# Growth Step: 754 of 1000
# Growth Step: 755 of 1000
# Growth Step: 756 of 1000
# Growth Step: 757 of 1000
# Growth Step: 758 of 1000
# Growth Step: 759 of 1000
# Growth Step: 760 of 1000
# Growth Step: 761 of 1000
# Growth Step: 762 of 1000
# Growth Step: 763 of 1000
# Growth Step: 764 of 1000
# Growth Step: 765 of 1000
# Growth Step: 766 of 1000
# Growth Step: 767 of 1000
# Growth Step: 768 of 1000
# Growth Step: 769 of 1000
# Growth Step: 770 of 1000
# Growth Step: 771 of 1000
# Growth Step: 772 of 1000
# Growth Step: 773 of 1000
# Growth Step: 774 of 1000
# Growth Step: 775 of 1000
# Growth Step: 776 of 1000
# Growth Step: 777 of 1000
# Growth Step: 778 of 1000
# Growth Step: 779 of 1000
# Growth Step: 780 of 1000
# Growth Step: 781 of 1000
# Growth Step: 782 of 1000
# Growth Step: 783 of 1000
# Growth Step: 784 of 1000
# Growth Step: 785 of 1000
# Growth Step: 786 of 1000
# Growth Step: 787 of 1000
# Growth Step: 788 of 1000
# Growth Step: 789 of 1000
# Growth Step: 790 of 1000
# Growth Step: 791 of 1000
# Growth Step: 792 of 1000
# Growth Step: 793 of 1000
# Growth Step: 794 of 1000
# Growth Step: 795 of 1000
# Growth Step: 796 of 1000
# Growth Step: 797 of 1000
# Growth Step: 798 of 1000
# Growth Step: 799 of 1000
# Growth Step: 800 of 1000
# Growth Step: 801 of 1000
# Growth Step: 802 of 1000
# Growth Step: 803 of 1000
# Growth Step: 804 of 1000
# Growth Step: 805 of 1000
# Growth Step: 806 of 1000
# Growth Step: 807 of 1000
# Growth Step: 808 of 1000
# Growth Step: 809 of 1000
# Growth Step: 810 of 1000
# Growth Step: 811 of 1000
# Growth Step: 812 of 1000
# Growth Step: 813 of 1000
# Growth Step: 814 of 1000
# Growth Step: 815 of 1000
# Growth Step: 816 of 1000
# Growth Step: 817 of 1000
# Growth Step: 818 of 1000
# Growth Step: 819 of 1000
# Growth Step: 820 of 1000
# Growth Step: 821 of 1000
# Growth Step: 822 of 1000
# Growth Step: 823 of 1000
# Growth Step: 824 of 1000
# Growth Step: 825 of 1000
# Growth Step: 826 of 1000
# Growth Step: 827 of 1000
# Growth Step: 828 of 1000
# Growth Step: 829 of 1000
# Growth Step: 830 of 1000
# Growth Step: 831 of 1000
# Growth Step: 832 of 1000
# Growth Step: 833 of 1000
# Growth Step: 834 of 1000
# Growth Step: 835 of 1000
# Growth Step: 836 of 1000
# Growth Step: 837 of 1000
# Growth Step: 838 of 1000
# Growth Step: 839 of 1000
# Growth Step: 840 of 1000
# Growth Step: 841 of 1000
# Growth Step: 842 of 1000
# Growth Step: 843 of 1000
# Growth Step: 844 of 1000
# Growth Step: 845 of 1000
# Growth Step: 846 of 1000
# Growth Step: 847 of 1000
# Growth Step: 848 of 1000
# Growth Step: 849 of 1000
# Growth Step: 850 of 1000
# Growth Step: 851 of 1000
# Growth Step: 852 of 1000
# Growth Step: 853 of 1000
# Growth Step: 854 of 1000
# Growth Step: 855 of 1000
# Growth Step: 856 of 1000
# Growth Step: 857 of 1000
# Growth Step: 858 of 1000
# Growth Step: 859 of 1000
# Growth Step: 860 of 1000
# Growth Step: 861 of 1000
# Growth Step: 862 of 1000
# Growth Step: 863 of 1000
# Growth Step: 864 of 1000
# Growth Step: 865 of 1000
# Growth Step: 866 of 1000
# Growth Step: 867 of 1000
# Growth Step: 868 of 1000
# Growth Step: 869 of 1000
# Growth Step: 870 of 1000
# Growth Step: 871 of 1000
# Growth Step: 872 of 1000
# Growth Step: 873 of 1000
# Growth Step: 874 of 1000
# Growth Step: 875 of 1000
# Growth Step: 876 of 1000
# Growth Step: 877 of 1000
# Growth Step: 878 of 1000
# Growth Step: 879 of 1000
# Growth Step: 880 of 1000
# Growth Step: 881 of 1000
# Growth Step: 882 of 1000
# Growth Step: 883 of 1000
# Growth Step: 884 of 1000
# Growth Step: 885 of 1000
# Growth Step: 886 of 1000
# Growth Step: 887 of 1000
# Growth Step: 888 of 1000
# Growth Step: 889 of 1000
# Growth Step: 890 of 1000
# Growth Step: 891 of 1000
# Growth Step: 892 of 1000
# Growth Step: 893 of 1000
# Growth Step: 894 of 1000
# Growth Step: 895 of 1000
# Growth Step: 896 of 1000
# Growth Step: 897 of 1000
# Growth Step: 898 of 1000
# Growth Step: 899 of 1000
# Growth Step: 900 of 1000
# Growth Step: 901 of 1000
# Growth Step: 902 of 1000
# Growth Step: 903 of 1000
# Growth Step: 904 of 1000
# Growth Step: 905 of 1000
# Growth Step: 906 of 1000
# Growth Step: 907 of 1000
# Growth Step: 908 of 1000
# Growth Step: 909 of 1000
# Growth Step: 910 of 1000
# Growth Step: 911 of 1000
# Growth Step: 912 of 1000
# Growth Step: 913 of 1000
# Growth Step: 914 of 1000
# Growth Step: 915 of 1000
# Growth Step: 916 of 1000
# Growth Step: 917 of 1000
# Growth Step: 918 of 1000
# Growth Step: 919 of 1000
# Growth Step: 920 of 1000
# Growth Step: 921 of 1000
# Growth Step: 922 of 1000
# Growth Step: 923 of 1000
# Growth Step: 924 of 1000
# Growth Step: 925 of 1000
# Growth Step: 926 of 1000
# Growth Step: 927 of 1000
# Growth Step: 928 of 1000
# Growth Step: 929 of 1000
# Growth Step: 930 of 1000
# Growth Step: 931 of 1000
# Growth Step: 932 of 1000
# Growth Step: 933 of 1000
# Growth Step: 934 of 1000
# Growth Step: 935 of 1000
# Growth Step: 936 of 1000
# Growth Step: 937 of 1000
# Growth Step: 938 of 1000
# Growth Step: 939 of 1000
# Growth Step: 940 of 1000
# Growth Step: 941 of 1000
# Growth Step: 942 of 1000
# Growth Step: 943 of 1000
# Growth Step: 944 of 1000
# Growth Step: 945 of 1000
# Growth Step: 946 of 1000
# Growth Step: 947 of 1000
# Growth Step: 948 of 1000
# Growth Step: 949 of 1000
# Growth Step: 950 of 1000
# Growth Step: 951 of 1000
# Growth Step: 952 of 1000
# Growth Step: 953 of 1000
# Growth Step: 954 of 1000
# Growth Step: 955 of 1000
# Growth Step: 956 of 1000
# Growth Step: 957 of 1000
# Growth Step: 958 of 1000
# Growth Step: 959 of 1000
# Growth Step: 960 of 1000
# Growth Step: 961 of 1000
# Growth Step: 962 of 1000
# Growth Step: 963 of 1000
# Growth Step: 964 of 1000
# Growth Step: 965 of 1000
# Growth Step: 966 of 1000
# Growth Step: 967 of 1000
# Growth Step: 968 of 1000
# Growth Step: 969 of 1000
# Growth Step: 970 of 1000
# Growth Step: 971 of 1000
# Growth Step: 972 of 1000
# Growth Step: 973 of 1000
# Growth Step: 974 of 1000
# Growth Step: 975 of 1000
# Growth Step: 976 of 1000
# Growth Step: 977 of 1000
# Growth Step: 978 of 1000
# Growth Step: 979 of 1000
# Growth Step: 980 of 1000
# Growth Step: 981 of 1000
# Growth Step: 982 of 1000
# Growth Step: 983 of 1000
# Growth Step: 984 of 1000
# Growth Step: 985 of 1000
# Growth Step: 986 of 1000
# Growth Step: 987 of 1000
# Growth Step: 988 of 1000
# Growth Step: 989 of 1000
# Growth Step: 990 of 1000
# Growth Step: 991 of 1000
# Growth Step: 992 of 1000
# Growth Step: 993 of 1000
# Growth Step: 994 of 1000
# Growth Step: 995 of 1000
# Growth Step: 996 of 1000
# Growth Step: 997 of 1000
# Growth Step: 998 of 1000
# Growth Step: 999 of 1000
# Growth Step: 1000 of 1000

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x298E6E10>
